# %%
import os; os.environ['CUDA_VISIBLE_DEVICES'] = "2"

# %%
import tensorflow; import keras
# Out:
# Using TensorFlow backend.

# %%
tensorflow.__version__
# Out:
# '1.2.0'

# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import csv
# %matplotlib inline

# %% [markdown]
# # Preprocessing the data

# %%
BASE_PATH = "/afs/csail.mit.edu/u/j/jains/6869-places"
DATA_PATH = os.path.join(BASE_PATH, 'data/images/')

# %% [markdown]
# ## Train Data
# The `data/images/train/` tree is organized like this: `<first_char>/<category_name>/<subcategory>`. This folder structure needs to be flattened to just `<category_name>`.
# So for example:
# ```
# train/
#     s/
#         subway_station/
#             platform/
#                 1.jpg
#                 ...
# ```
# needs to be turned into
# ```
# train/
#     subway_station-platform/
#         1.jpg
# ```
# for all categories. This is to make it easier for Keras' ImageDataGenerator.flow_from_directory() to identify the categories automatically.

# %%
TRAIN_PATH = os.path.join(DATA_PATH, "train/")

categories = os.listdir(TRAIN_PATH)
len(categories), categories
# Out:
# (100,
#  ['fire_station',
#   'kitchen',
#   'abbey',
#   'racecourse',
#   'valley',
#   'track-outdoor',
#   'harbor',
#   'office',
#   'iceberg',
#   'palace',
#   'yard',
#   'laundromat',
#   'campsite',
#   'shed',
#   'gas_station',
#   'market-outdoor',
#   'badlands',
#   'lighthouse',
#   'dam',
#   'desert-sand',
#   'dining_room',
#   'driveway',
#   'airport_terminal',
#   'amphitheater',
#   'amusement_park',
#   'aquarium',
#   'aqueduct',
#   'art_gallery',
#   'assembly_line',
#   'auditorium',
#   'bakery-shop',
#   'ballroom',
#   'bamboo_forest',
#   'banquet_hall',
#   'bar',
#   'baseball_field',
#   'bathroom',
#   'beauty_salon',
#   'bedroom',
#   'boat_deck',
#   'bookstore',
#   'botanical_garden',
#   'bowling_alley',
#   'boxing_ring',
#   'bridge',
#   'bus_interior',
#   'butchers_shop',
#   'candy_store',
#   'canyon',
#   'cemetery',
#   'chalet',
#   'church-outdoor',
#   'classroom',
#   'clothing_store',
#   'coast',
#   'cockpit',
#   'coffee_shop',
#   'conference_room',
#   'construction_site',
#   'corn_field',
#   'corridor',
#   'courtyard',
#   'food_court',
#   'fountain',
#   'golf_course',
#   'ice_skating_rink-outdoor',
#   'kindergarden_classroom',
#   'living_room',
#   'lobby',
#   'locker_room',
#   'martial_arts_gym',
#   'monastery-outdoor',
#   'mountain',
#   'museum-indoor',
#   'parking_lot',
#   'phone_booth',
#   'playground',
#   'railroad_track',
#   'rainforest',
#   'restaurant',
#   'river',
#   'rock_arch',
#   'runway',
#   'shower',
#   'ski_slope',
#   'skyscraper',
#   'slum',
#   'stadium-football',
#   'stage-indoor',
#   'staircase',
#   'subway_station-platform',
#   'supermarket',
#   'swamp',
#   'swimming_pool-outdoor',
#   'temple-east_asia',
#   'trench',
#   'volcano',
#   'highway',
#   'hospital_room',
#   'hot_spring'])

# %% [markdown]
# ## Validation Data
# The `data/val` tree is organized as a bunch of unlabeled jpgs. Process this into the same structure as you did the training data.

# %%
VAL_PATH = os.path.join(DATA_PATH, "val/")
VAL_LABEL_PATH = os.path.join(BASE_PATH, "development_kit/data/val-mine.txt")

# %%
cat_num_to_name = {}

CATEGORIES_PATH = os.path.join(BASE_PATH, "development_kit/data/categories.txt")
with open(CATEGORIES_PATH, 'r') as f:
    reader = csv.reader(f, delimiter=' ')
    for row in reader:
        label = row[0]
        parts = row[0].split('/')
        if len(parts) > 3:
            label = parts[2] + '-' + parts[3]
        else:
            label = parts[2]
        cat_num_to_name[int(row[1])] = label

# Check categories match exactly with train categories
assert set(cat_num_to_name.values()) == set(categories)

cat_num_to_name
# Out:
# {0: 'abbey',
#  1: 'airport_terminal',
#  2: 'amphitheater',
#  3: 'amusement_park',
#  4: 'aquarium',
#  5: 'aqueduct',
#  6: 'art_gallery',
#  7: 'assembly_line',
#  8: 'auditorium',
#  9: 'badlands',
#  10: 'bakery-shop',
#  11: 'ballroom',
#  12: 'bamboo_forest',
#  13: 'banquet_hall',
#  14: 'bar',
#  15: 'baseball_field',
#  16: 'bathroom',
#  17: 'beauty_salon',
#  18: 'bedroom',
#  19: 'boat_deck',
#  20: 'bookstore',
#  21: 'botanical_garden',
#  22: 'bowling_alley',
#  23: 'boxing_ring',
#  24: 'bridge',
#  25: 'bus_interior',
#  26: 'butchers_shop',
#  27: 'campsite',
#  28: 'candy_store',
#  29: 'canyon',
#  30: 'cemetery',
#  31: 'chalet',
#  32: 'church-outdoor',
#  33: 'classroom',
#  34: 'clothing_store',
#  35: 'coast',
#  36: 'cockpit',
#  37: 'coffee_shop',
#  38: 'conference_room',
#  39: 'construction_site',
#  40: 'corn_field',
#  41: 'corridor',
#  42: 'courtyard',
#  43: 'dam',
#  44: 'desert-sand',
#  45: 'dining_room',
#  46: 'driveway',
#  47: 'fire_station',
#  48: 'food_court',
#  49: 'fountain',
#  50: 'gas_station',
#  51: 'golf_course',
#  52: 'harbor',
#  53: 'highway',
#  54: 'hospital_room',
#  55: 'hot_spring',
#  56: 'ice_skating_rink-outdoor',
#  57: 'iceberg',
#  58: 'kindergarden_classroom',
#  59: 'kitchen',
#  60: 'laundromat',
#  61: 'lighthouse',
#  62: 'living_room',
#  63: 'lobby',
#  64: 'locker_room',
#  65: 'market-outdoor',
#  66: 'martial_arts_gym',
#  67: 'monastery-outdoor',
#  68: 'mountain',
#  69: 'museum-indoor',
#  70: 'office',
#  71: 'palace',
#  72: 'parking_lot',
#  73: 'phone_booth',
#  74: 'playground',
#  75: 'racecourse',
#  76: 'railroad_track',
#  77: 'rainforest',
#  78: 'restaurant',
#  79: 'river',
#  80: 'rock_arch',
#  81: 'runway',
#  82: 'shed',
#  83: 'shower',
#  84: 'ski_slope',
#  85: 'skyscraper',
#  86: 'slum',
#  87: 'stadium-football',
#  88: 'stage-indoor',
#  89: 'staircase',
#  90: 'subway_station-platform',
#  91: 'supermarket',
#  92: 'swamp',
#  93: 'swimming_pool-outdoor',
#  94: 'temple-east_asia',
#  95: 'track-outdoor',
#  96: 'trench',
#  97: 'valley',
#  98: 'volcano',
#  99: 'yard'}

# %%
filename_to_category = {}

with open(VAL_LABEL_PATH, 'r') as f:
#  '00003389.jpg': 47,
#  '00005758.jpg': 33,
#  '00003157.jpg': 48,
#  '00005954.jpg': 92,
#  '00005654.jpg': 37,
#  '00003956.jpg': 88,
#  '00003531.jpg': 72,
#  '00001507.jpg': 6,
#  '00000667.jpg': 87,
#  '00004549.jpg': 70,
#  '00002487.jpg': 45,
#  '00001084.jpg': 49,
#  '00009047.jpg': 97,
#  '00006002.jpg': 86,
#  '00000938.jpg': 91,
#  '00001966.jpg': 18,
#  '00009314.jpg': 5,
#  '00000191.jpg': 72,
#  '00001858.jpg': 93,
#  '00004673.jpg': 25,
#  '00003272.jpg': 59,
#  '00001180.jpg': 91,
#  '00007071.jpg': 81,
#  '00004345.jpg': 31,
#  '00003056.jpg': 84,
#  '00000058.jpg': 26,
#  '00002707.jpg': 16,
#  '00005983.jpg': 16,
#  '00007048.jpg': 22,
#  '00002160.jpg': 88,
#  '00001383.jpg': 28,
#  '00002630.jpg': 55,
#  '00009744.jpg': 97,
#  '00009727.jpg': 52,
#  '00007938.jpg': 60,
#  '00006795.jpg': 37,
#  '00006960.jpg': 99,
#  '00004687.jpg': 45,
#  '00007019.jpg': 93,
#  '00008563.jpg': 18,
#  '00000317.jpg': 5,
#  '00005704.jpg': 60,
#  '00007683.jpg': 75,
#  '00005917.jpg': 24,
#  '00003159.jpg': 75,
#  '00005055.jpg': 78,
#  '00002163.jpg': 56,
#  '00007023.jpg': 69,
#  '00001357.jpg': 59,
#  '00000942.jpg': 61,
#  '00007188.jpg': 4,
#  '00007589.jpg': 17,
#  '00002411.jpg': 16,
#  '00002967.jpg': 86,
#  '00002398.jpg': 72,
#  '00002964.jpg': 95,
#  '00002953.jpg': 76,
#  '00009970.jpg': 74,
#  '00008363.jpg': 35,
#  '00005477.jpg': 87,
#  '00000542.jpg': 99,
#  '00005515.jpg': 44,
#  '00007864.jpg': 71,
#  '00000715.jpg': 57,
#  '00005537.jpg': 94,
#  '00001127.jpg': 76,
#  '00000063.jpg': 67,
#  '00000268.jpg': 78,
#  '00009299.jpg': 89,
#  '00008124.jpg': 66,
#  ...}

# %%
filename_to_name = {}

for filename, cat in filename_to_category.items():
    filename_to_name[filename] = cat_num_to_name[cat]

filename_to_name
# Out:
# {'00007487.jpg': 'playground',
#  '00002675.jpg': 'restaurant',
#  '00006449.jpg': 'yard',
#  '00006612.jpg': 'market-outdoor',
#  '00002929.jpg': 'office',
#  '00008137.jpg': 'martial_arts_gym',
#  '00003487.jpg': 'bus_interior',
#  '00006424.jpg': 'supermarket',
#  '00005125.jpg': 'baseball_field',
#  '00003677.jpg': 'banquet_hall',
#  '00006819.jpg': 'market-outdoor',
#  '00000403.jpg': 'banquet_hall',
#  '00003318.jpg': 'beauty_salon',
#  '00001515.jpg': 'butchers_shop',
#  '00001460.jpg': 'classroom',
#  '00004614.jpg': 'rainforest',
#  '00009289.jpg': 'bookstore',
#  '00005915.jpg': 'butchers_shop',
#  '00000880.jpg': 'gas_station',
#  '00007253.jpg': 'boat_deck',
#  '00005585.jpg': 'conference_room',
#  '00000176.jpg': 'dining_room',
#  '00000837.jpg': 'bus_interior',
#  '00002195.jpg': 'cemetery',
#  '00005438.jpg': 'staircase',
#  '00000277.jpg': 'locker_room',
#  '00005564.jpg': 'coffee_shop',
#  '00007053.jpg': 'clothing_store',
#  '00007335.jpg': 'living_room',
#  '00001266.jpg': 'martial_arts_gym',
#  '00004503.jpg': 'office',
#  '00007442.jpg': 'supermarket',
#  '00009902.jpg': 'shed',
#  '00005119.jpg': 'shower',
#  '00000705.jpg': 'living_room',
#  '00009232.jpg': 'courtyard',
#  '00006794.jpg': 'desert-sand',
#  '00009915.jpg': 'fire_station',
#  '00006734.jpg': 'bamboo_forest',
#  '00003023.jpg': 'playground',
#  '00009420.jpg': 'amusement_park',
#  '00003620.jpg': 'river',
#  '00006362.jpg': 'runway',
#  '00004850.jpg': 'runway',
#  '00001602.jpg': 'racecourse',
#  '00005369.jpg': 'yard',
#  '00003743.jpg': 'ice_skating_rink-outdoor',
#  '00009230.jpg': 'courtyard',
#  '00008815.jpg': 'swimming_pool-outdoor',
#  '00003100.jpg': 'aqueduct',
#  '00005607.jpg': 'corridor',
#  '00007538.jpg': 'living_room',
#  '00001375.jpg': 'skyscraper',
#  '00004008.jpg': 'butchers_shop',
#  '00003964.jpg': 'rock_arch',
#  '00002645.jpg': 'butchers_shop',
#  '00003202.jpg': 'track-outdoor',
#  '00009587.jpg': 'baseball_field',
#  '00006902.jpg': 'coffee_shop',
#  '00000017.jpg': 'corridor',
#  '00005920.jpg': 'abbey',
#  '00002917.jpg': 'bar',
#  '00001497.jpg': 'martial_arts_gym',
#  '00001186.jpg': 'banquet_hall',
#  '00007738.jpg': 'restaurant',
#  '00009817.jpg': 'desert-sand',
#  '00009257.jpg': 'canyon',
#  '00002129.jpg': 'botanical_garden',
#  '00007236.jpg': 'badlands',
#  '00004804.jpg': 'parking_lot',
#  '00007090.jpg': 'cemetery',
#  '00004901.jpg': 'lobby',
#  '00001551.jpg': 'classroom',
#  '00001694.jpg': 'banquet_hall',
#  '00007089.jpg': 'shower',
#  '00002958.jpg': 'stage-indoor',
#  '00001119.jpg': 'volcano',
#  '00001762.jpg': 'clothing_store',
#  '00004232.jpg': 'boat_deck',
#  '00008654.jpg': 'bar',
#  '00001248.jpg': 'racecourse',
#  '00002780.jpg': 'bowling_alley',
#  '00001116.jpg': 'swamp',
#  '00008891.jpg': 'cemetery',
#  '00005346.jpg': 'bar',
#  '00008705.jpg': 'abbey',
#  '00002165.jpg': 'conference_room',
#  '00001039.jpg': 'aqueduct',
#  '00003941.jpg': 'yard',
#  '00002934.jpg': 'golf_course',
#  '00003820.jpg': 'botanical_garden',
#  '00004186.jpg': 'market-outdoor',
#  '00000896.jpg': 'boxing_ring',
#  '00003767.jpg': 'market-outdoor',
#  '00009028.jpg': 'construction_site',
#  '00008674.jpg': 'bamboo_forest',
#  '00005751.jpg': 'banquet_hall',
#  '00008987.jpg': 'butchers_shop',
#  '00009431.jpg': 'fire_station',
#  '00002471.jpg': 'martial_arts_gym',
#  '00009668.jpg': 'badlands',
#  '00001931.jpg': 'valley',
#  '00003729.jpg': 'restaurant',
#  '00007289.jpg': 'trench',
#  '00006483.jpg': 'gas_station',
#  '00001436.jpg': 'ski_slope',
#  '00001346.jpg': 'abbey',
#  '00000931.jpg': 'courtyard',
#  '00004389.jpg': 'aquarium',
#  '00001732.jpg': 'bathroom',
#  '00002621.jpg': 'dining_room',
#  '00001233.jpg': 'iceberg',
#  '00008378.jpg': 'bakery-shop',
#  '00003161.jpg': 'courtyard',
#  '00006722.jpg': 'playground',
#  '00000107.jpg': 'monastery-outdoor',
#  '00004500.jpg': 'museum-indoor',
#  '00001874.jpg': 'coffee_shop',
#  '00008204.jpg': 'temple-east_asia',
#  '00006998.jpg': 'swimming_pool-outdoor',
#  '00005351.jpg': 'conference_room',
#  '00002381.jpg': 'corn_field',
#  '00006814.jpg': 'bathroom',
#  '00004835.jpg': 'living_room',
#  '00002311.jpg': 'art_gallery',
#  '00009046.jpg': 'laundromat',
#  '00007210.jpg': 'conference_room',
#  '00007338.jpg': 'river',
#  '00002848.jpg': 'aquarium',
#  '00006033.jpg': 'skyscraper',
#  '00000225.jpg': 'ski_slope',
#  '00004110.jpg': 'airport_terminal',
#  '00000306.jpg': 'desert-sand',
#  '00001259.jpg': 'driveway',
#  '00003244.jpg': 'coffee_shop',
#  '00002781.jpg': 'rock_arch',
#  '00002713.jpg': 'office',
#  '00007989.jpg': 'banquet_hall',
#  '00000482.jpg': 'locker_room',
#  '00000010.jpg': 'kitchen',
#  '00001391.jpg': 'highway',
#  '00007178.jpg': 'slum',
#  '00006807.jpg': 'shed',
#  '00006100.jpg': 'baseball_field',
#  '00006077.jpg': 'highway',
#  '00007280.jpg': 'campsite',
#  '00006002.jpg': 'slum',
#  '00008863.jpg': 'bar',
#  '00007950.jpg': 'river',
#  '00007130.jpg': 'auditorium',
#  '00000432.jpg': 'cemetery',
#  '00001315.jpg': 'bus_interior',
#  '00004182.jpg': 'bathroom',
#  '00006621.jpg': 'subway_station-platform',
#  '00005554.jpg': 'phone_booth',
#  '00003924.jpg': 'art_gallery',
#  '00004649.jpg': 'candy_store',
#  '00008303.jpg': 'candy_store',
#  '00005716.jpg': 'stage-indoor',
#  '00006150.jpg': 'museum-indoor',
#  '00002649.jpg': 'chalet',
#  '00002841.jpg': 'stage-indoor',
#  '00003339.jpg': 'museum-indoor',
#  '00007165.jpg': 'driveway',
#  '00007373.jpg': 'palace',
#  '00009498.jpg': 'cemetery',
#  '00001396.jpg': 'bowling_alley',
#  '00006070.jpg': 'bamboo_forest',
#  '00009539.jpg': 'assembly_line',
#  '00007252.jpg': 'kindergarden_classroom',
#  '00002679.jpg': 'bridge',
#  '00004031.jpg': 'playground',
#  '00006313.jpg': 'bus_interior',
#  '00005018.jpg': 'river',
#  '00003150.jpg': 'phone_booth',
#  '00000994.jpg': 'butchers_shop',
#  '00007398.jpg': 'swamp',
#  '00009477.jpg': 'chalet',
#  '00006656.jpg': 'ski_slope',
#  '00004959.jpg': 'museum-indoor',
#  '00005728.jpg': 'swimming_pool-outdoor',
#  '00002250.jpg': 'canyon',
#  '00007754.jpg': 'construction_site',
#  '00007039.jpg': 'railroad_track',
#  '00001009.jpg': 'museum-indoor',
#  '00002711.jpg': 'volcano',
#  '00005177.jpg': 'rainforest',
#  '00000416.jpg': 'yard',
#  '00004566.jpg': 'bus_interior',
#  '00008683.jpg': 'mountain',
#  '00005326.jpg': 'classroom',
#  '00006192.jpg': 'restaurant',
#  '00000711.jpg': 'golf_course',
#  '00007305.jpg': 'aquarium',
#  '00008870.jpg': 'amusement_park',
#  '00005441.jpg': 'racecourse',
#  '00002806.jpg': 'office',
#  '00008898.jpg': 'amusement_park',
#  '00005275.jpg': 'coffee_shop',
#  '00005215.jpg': 'bridge',
#  '00002733.jpg': 'subway_station-platform',
#  '00007959.jpg': 'boat_deck',
#  '00003833.jpg': 'museum-indoor',
#  '00004273.jpg': 'ski_slope',
#  '00002002.jpg': 'coffee_shop',
#  '00000104.jpg': 'abbey',
#  '00008864.jpg': 'auditorium',
#  '00000300.jpg': 'stadium-football',
#  '00003790.jpg': 'golf_course',
#  '00002451.jpg': 'ballroom',
#  '00007243.jpg': 'supermarket',
#  '00003660.jpg': 'restaurant',
#  '00008835.jpg': 'chalet',
#  '00000493.jpg': 'dam',
#  '00009608.jpg': 'highway',
#  '00002192.jpg': 'church-outdoor',
#  '00002157.jpg': 'aqueduct',
#  '00006633.jpg': 'candy_store',
#  '00002201.jpg': 'rainforest',
#  '00008115.jpg': 'classroom',
#  '00000722.jpg': 'rock_arch',
#  '00000548.jpg': 'chalet',
#  '00003290.jpg': 'volcano',
#  '00002812.jpg': 'kitchen',
#  '00004355.jpg': 'desert-sand',
#  '00002678.jpg': 'dining_room',
#  '00008272.jpg': 'parking_lot',
#  '00002618.jpg': 'lighthouse',
#  '00004202.jpg': 'iceberg',
#  '00003636.jpg': 'ballroom',
#  '00002907.jpg': 'church-outdoor',
#  '00009304.jpg': 'playground',
#  '00005638.jpg': 'cemetery',
#  '00009924.jpg': 'river',
#  '00004715.jpg': 'dam',
#  '00004815.jpg': 'museum-indoor',
#  '00008217.jpg': 'badlands',
#  '00006144.jpg': 'subway_station-platform',
#  '00009535.jpg': 'hospital_room',
#  '00004003.jpg': 'highway',
#  '00005336.jpg': 'playground',
#  '00001273.jpg': 'fire_station',
#  '00000155.jpg': 'fountain',
#  '00005273.jpg': 'clothing_store',
#  '00008462.jpg': 'locker_room',
#  '00001348.jpg': 'bus_interior',
#  '00008797.jpg': 'dam',
#  '00003106.jpg': 'valley',
#  '00004603.jpg': 'cockpit',
#  '00007164.jpg': 'temple-east_asia',
#  '00002905.jpg': 'mountain',
#  '00009362.jpg': 'coast',
#  '00004774.jpg': 'playground',
#  '00000724.jpg': 'staircase',
#  '00000755.jpg': 'lighthouse',
#  '00006321.jpg': 'cemetery',
#  '00002218.jpg': 'fire_station',
#  '00009963.jpg': 'bar',
#  '00003086.jpg': 'fountain',
#  '00004258.jpg': 'stage-indoor',
#  '00001683.jpg': 'boat_deck',
#  '00006888.jpg': 'highway',
#  '00006637.jpg': 'bus_interior',
#  '00001876.jpg': 'bamboo_forest',
#  '00000533.jpg': 'church-outdoor',
#  '00003831.jpg': 'hot_spring',
#  '00009298.jpg': 'runway',
#  '00000418.jpg': 'boat_deck',
#  '00007344.jpg': 'office',
#  '00005495.jpg': 'hot_spring',
#  '00004689.jpg': 'corridor',
#  '00004803.jpg': 'coast',
#  '00002093.jpg': 'fire_station',
#  '00004054.jpg': 'swamp',
#  '00001977.jpg': 'palace',
#  '00004255.jpg': 'subway_station-platform',
#  '00009738.jpg': 'bar',
#  '00007702.jpg': 'church-outdoor',
#  '00005464.jpg': 'temple-east_asia',
#  '00002320.jpg': 'cemetery',
#  '00001217.jpg': 'volcano',
#  '00000606.jpg': 'rock_arch',
#  '00006236.jpg': 'martial_arts_gym',
#  '00003210.jpg': 'botanical_garden',
#  '00005526.jpg': 'parking_lot',
#  '00004612.jpg': 'mountain',
#  '00000410.jpg': 'stage-indoor',
#  '00003132.jpg': 'coast',
#  '00002037.jpg': 'slum',
#  '00002328.jpg': 'banquet_hall',
#  '00000467.jpg': 'martial_arts_gym',
#  '00001830.jpg': 'boat_deck',
#  '00002909.jpg': 'boat_deck',
#  '00007304.jpg': 'campsite',
#  '00008004.jpg': 'dining_room',
#  '00008927.jpg': 'airport_terminal',
#  '00003863.jpg': 'bridge',
#  '00007871.jpg': 'corridor',
#  '00005149.jpg': 'subway_station-platform',
#  '00003181.jpg': 'art_gallery',
#  '00000302.jpg': 'boxing_ring',
#  '00002036.jpg': 'food_court',
#  '00004896.jpg': 'airport_terminal',
#  '00000792.jpg': 'swimming_pool-outdoor',
#  '00006055.jpg': 'chalet',
#  '00005490.jpg': 'fountain',
#  '00004546.jpg': 'hospital_room',
#  '00002672.jpg': 'gas_station',
#  '00006675.jpg': 'aquarium',
#  '00007727.jpg': 'highway',
#  '00008209.jpg': 'boat_deck',
#  '00004338.jpg': 'bar',
#  '00007830.jpg': 'courtyard',
#  '00002680.jpg': 'shed',
#  '00001873.jpg': 'stadium-football',
#  '00000709.jpg': 'phone_booth',
#  '00006815.jpg': 'railroad_track',
#  '00007222.jpg': 'badlands',
#  '00004160.jpg': 'ski_slope',
#  '00004162.jpg': 'dam',
#  '00004720.jpg': 'bamboo_forest',
#  '00000202.jpg': 'campsite',
#  '00006937.jpg': 'amphitheater',
#  '00009355.jpg': 'abbey',
#  '00000050.jpg': 'botanical_garden',
#  '00008802.jpg': 'bowling_alley',
#  '00006348.jpg': 'auditorium',
#  '00005013.jpg': 'ballroom',
#  '00007904.jpg': 'hospital_room',
#  '00003682.jpg': 'coffee_shop',
#  '00008274.jpg': 'supermarket',
#  '00000882.jpg': 'aqueduct',
#  '00001364.jpg': 'skyscraper',
#  '00005141.jpg': 'abbey',
#  '00001759.jpg': 'living_room',
#  '00001843.jpg': 'candy_store',
#  '00003594.jpg': 'market-outdoor',
#  '00008744.jpg': 'boxing_ring',
#  '00006302.jpg': 'shed',
#  '00002880.jpg': 'construction_site',
#  '00004866.jpg': 'kindergarden_classroom',
#  '00005077.jpg': 'supermarket',
#  '00002721.jpg': 'stadium-football',
#  '00008489.jpg': 'kitchen',
#  '00008791.jpg': 'racecourse',
#  '00002491.jpg': 'aqueduct',
#  '00001059.jpg': 'amphitheater',
#  '00006973.jpg': 'temple-east_asia',
#  '00004605.jpg': 'baseball_field',
#  '00009236.jpg': 'candy_store',
#  '00005469.jpg': 'gas_station',
#  '00000640.jpg': 'food_court',
#  '00003665.jpg': 'golf_course',
#  '00000908.jpg': 'boat_deck',
#  '00001549.jpg': 'bathroom',
#  '00001540.jpg': 'food_court',
#  '00002922.jpg': 'ice_skating_rink-outdoor',
#  '00001193.jpg': 'bookstore',
#  '00002937.jpg': 'railroad_track',
#  '00004228.jpg': 'swamp',
#  '00005664.jpg': 'art_gallery',
#  '00008241.jpg': 'art_gallery',
#  '00001296.jpg': 'yard',
#  '00004408.jpg': 'dam',
#  '00000331.jpg': 'canyon',
#  '00005533.jpg': 'rainforest',
#  '00001419.jpg': 'airport_terminal',
#  '00002792.jpg': 'canyon',
#  '00009570.jpg': 'hot_spring',
#  '00005226.jpg': 'hot_spring',
#  '00004240.jpg': 'fountain',
#  '00002668.jpg': 'temple-east_asia',
#  '00004278.jpg': 'desert-sand',
#  '00007867.jpg': 'playground',
#  '00001304.jpg': 'baseball_field',
#  '00007227.jpg': 'shed',
#  '00000201.jpg': 'corn_field',
#  '00005377.jpg': 'monastery-outdoor',
#  '00009884.jpg': 'desert-sand',
#  '00001164.jpg': 'living_room',
#  '00004429.jpg': 'skyscraper',
#  '00005049.jpg': 'banquet_hall',
#  '00003035.jpg': 'bookstore',
#  '00002631.jpg': 'swamp',
#  '00007359.jpg': 'railroad_track',
#  '00004596.jpg': 'railroad_track',
#  '00007733.jpg': 'coffee_shop',
#  '00002197.jpg': 'canyon',
#  '00002448.jpg': 'laundromat',
#  '00004819.jpg': 'clothing_store',
#  '00005132.jpg': 'badlands',
#  '00006225.jpg': 'bar',
#  '00008298.jpg': 'yard',
#  '00007965.jpg': 'fountain',
#  '00000113.jpg': 'slum',
#  '00004469.jpg': 'canyon',
#  '00004430.jpg': 'phone_booth',
#  '00003535.jpg': 'amphitheater',
#  '00005124.jpg': 'fire_station',
#  '00001197.jpg': 'bedroom',
#  '00000643.jpg': 'staircase',
#  '00003320.jpg': 'clothing_store',
#  '00000333.jpg': 'ballroom',
#  '00008836.jpg': 'canyon',
#  '00000091.jpg': 'valley',
#  '00001275.jpg': 'railroad_track',
#  '00006491.jpg': 'beauty_salon',
#  '00004038.jpg': 'boat_deck',
#  '00000773.jpg': 'stage-indoor',
#  '00001909.jpg': 'ski_slope',
#  '00001863.jpg': 'cemetery',
#  '00000682.jpg': 'airport_terminal',
#  '00001577.jpg': 'river',
#  '00006754.jpg': 'conference_room',
#  '00005016.jpg': 'phone_booth',
#  '00000642.jpg': 'banquet_hall',
#  '00000003.jpg': 'beauty_salon',
#  '00004912.jpg': 'bowling_alley',
#  '00009651.jpg': 'playground',
#  '00006951.jpg': 'bamboo_forest',
#  '00005056.jpg': 'valley',
#  '00004380.jpg': 'airport_terminal',
#  '00002504.jpg': 'chalet',
#  '00000023.jpg': 'palace',
#  '00003293.jpg': 'skyscraper',
#  '00005094.jpg': 'rock_arch',
#  '00009650.jpg': 'bridge',
#  '00001875.jpg': 'racecourse',
#  '00002541.jpg': 'railroad_track',
#  '00008676.jpg': 'martial_arts_gym',
#  '00007120.jpg': 'abbey',
#  '00008063.jpg': 'harbor',
#  '00001409.jpg': 'bridge',
#  '00008361.jpg': 'temple-east_asia',
#  '00008755.jpg': 'boxing_ring',
#  '00008002.jpg': 'hot_spring',
#  '00002071.jpg': 'palace',
#  '00002344.jpg': 'campsite',
#  '00005129.jpg': 'mountain',
#  '00001599.jpg': 'playground',
#  '00000490.jpg': 'baseball_field',
#  '00000989.jpg': 'auditorium',
#  '00008991.jpg': 'railroad_track',
#  '00006288.jpg': 'cemetery',
#  '00001334.jpg': 'aquarium',
#  '00005181.jpg': 'beauty_salon',
#  '00007486.jpg': 'ballroom',
#  '00003129.jpg': 'beauty_salon',
#  '00000479.jpg': 'bamboo_forest',
#  '00004898.jpg': 'lighthouse',
#  '00005785.jpg': 'swimming_pool-outdoor',
#  '00001377.jpg': 'bathroom',
#  '00000561.jpg': 'courtyard',
#  '00009851.jpg': 'martial_arts_gym',
#  '00009347.jpg': 'staircase',
#  '00003935.jpg': 'bowling_alley',
#  '00007448.jpg': 'ballroom',
#  '00003109.jpg': 'driveway',
#  '00003897.jpg': 'badlands',
#  '00007361.jpg': 'aquarium',
#  '00004144.jpg': 'bowling_alley',
#  '00009314.jpg': 'aqueduct',
#  '00007919.jpg': 'palace',
#  '00000262.jpg': 'hospital_room',
#  '00001705.jpg': 'skyscraper',
#  '00000209.jpg': 'ice_skating_rink-outdoor',
#  '00008764.jpg': 'bathroom',
#  '00006942.jpg': 'courtyard',
#  '00001697.jpg': 'beauty_salon',
#  '00005208.jpg': 'swamp',
#  '00003367.jpg': 'parking_lot',
#  '00004147.jpg': 'lobby',
#  '00003060.jpg': 'bathroom',
#  '00002647.jpg': 'candy_store',
#  '00004925.jpg': 'aqueduct',
#  '00008027.jpg': 'bar',
#  '00005847.jpg': 'highway',
#  '00002272.jpg': 'laundromat',
#  '00001672.jpg': 'fountain',
#  '00001829.jpg': 'fire_station',
#  '00000218.jpg': 'bamboo_forest',
#  '00008092.jpg': 'hospital_room',
#  '00004200.jpg': 'boat_deck',
#  '00001621.jpg': 'cockpit',
#  '00005366.jpg': 'river',
#  '00002924.jpg': 'lighthouse',
#  '00006604.jpg': 'racecourse',
#  '00004033.jpg': 'assembly_line',
#  '00001786.jpg': 'palace',
#  '00002321.jpg': 'phone_booth',
#  '00004416.jpg': 'cockpit',
#  '00009105.jpg': 'dam',
#  '00000265.jpg': 'art_gallery',
#  '00007155.jpg': 'museum-indoor',
#  '00002765.jpg': 'courtyard',
#  '00006708.jpg': 'parking_lot',
#  '00004369.jpg': 'palace',
#  '00009657.jpg': 'parking_lot',
#  '00001652.jpg': 'yard',
#  '00009018.jpg': 'boat_deck',
#  '00000581.jpg': 'martial_arts_gym',
#  '00009985.jpg': 'gas_station',
#  '00002629.jpg': 'runway',
#  '00009329.jpg': 'campsite',
#  '00004682.jpg': 'banquet_hall',
#  '00004317.jpg': 'fire_station',
#  '00005672.jpg': 'cockpit',
#  '00001680.jpg': 'airport_terminal',
#  '00005762.jpg': 'abbey',
#  '00006215.jpg': 'bookstore',
#  '00003987.jpg': 'martial_arts_gym',
#  '00006136.jpg': 'ballroom',
#  '00002963.jpg': 'highway',
#  '00001265.jpg': 'mountain',
#  '00004808.jpg': 'boxing_ring',
#  '00009003.jpg': 'bar',
#  '00006251.jpg': 'stage-indoor',
#  '00007890.jpg': 'trench',
#  '00002004.jpg': 'phone_booth',
#  '00001429.jpg': 'airport_terminal',
#  '00003047.jpg': 'stadium-football',
#  '00003330.jpg': 'rock_arch',
#  '00004052.jpg': 'cockpit',
#  '00009099.jpg': 'river',
#  '00002515.jpg': 'volcano',
#  '00001013.jpg': 'railroad_track',
#  '00009843.jpg': 'phone_booth',
#  '00002662.jpg': 'mountain',
#  '00008450.jpg': 'clothing_store',
#  '00004329.jpg': 'coffee_shop',
#  '00003640.jpg': 'beauty_salon',
#  '00004370.jpg': 'lighthouse',
#  '00000547.jpg': 'abbey',
#  '00000022.jpg': 'fire_station',
#  '00005750.jpg': 'dining_room',
#  '00006383.jpg': 'food_court',
#  '00005489.jpg': 'corridor',
#  '00003659.jpg': 'hospital_room',
#  '00000237.jpg': 'amphitheater',
#  '00007244.jpg': 'temple-east_asia',
#  '00004284.jpg': 'racecourse',
#  '00000579.jpg': 'track-outdoor',
#  '00007140.jpg': 'swimming_pool-outdoor',
#  '00002228.jpg': 'corn_field',
#  '00002011.jpg': 'aqueduct',
#  '00000256.jpg': 'beauty_salon',
#  '00006115.jpg': 'bridge',
#  '00007741.jpg': 'yard',
#  '00001148.jpg': 'river',
#  '00002477.jpg': 'canyon',
#  '00007931.jpg': 'parking_lot',
#  '00005068.jpg': 'rainforest',
#  '00008519.jpg': 'abbey',
#  '00003652.jpg': 'coffee_shop',
#  '00009488.jpg': 'amusement_park',
#  '00003908.jpg': 'classroom',
#  '00006019.jpg': 'river',
#  '00003945.jpg': 'swimming_pool-outdoor',
#  '00006780.jpg': 'ski_slope',
#  '00002389.jpg': 'mountain',
#  '00004581.jpg': 'harbor',
#  '00000538.jpg': 'campsite',
#  '00000353.jpg': 'iceberg',
#  '00005677.jpg': 'amphitheater',
#  '00007061.jpg': 'bookstore',
#  '00004671.jpg': 'amphitheater',
#  '00002078.jpg': 'assembly_line',
#  '00004276.jpg': 'living_room',
#  '00009759.jpg': 'railroad_track',
#  '00002380.jpg': 'track-outdoor',
#  '00005003.jpg': 'track-outdoor',
#  '00000676.jpg': 'corn_field',
#  '00002589.jpg': 'candy_store',
#  '00003646.jpg': 'ice_skating_rink-outdoor',
#  '00006725.jpg': 'locker_room',
#  '00003853.jpg': 'badlands',
#  '00001582.jpg': 'amphitheater',
#  '00005989.jpg': 'chalet',
#  '00009445.jpg': 'dam',
#  '00002109.jpg': 'courtyard',
#  '00001125.jpg': 'ballroom',
#  '00004323.jpg': 'valley',
#  '00003294.jpg': 'valley',
#  '00003837.jpg': 'golf_course',
#  '00000956.jpg': 'canyon',
#  '00007050.jpg': 'bowling_alley',
#  '00002769.jpg': 'bowling_alley',
#  '00007973.jpg': 'kitchen',
#  '00003499.jpg': 'bathroom',
#  '00008534.jpg': 'cockpit',
#  '00001717.jpg': 'hot_spring',
#  '00003288.jpg': 'river',
#  '00002226.jpg': 'lighthouse',
#  '00008546.jpg': 'stage-indoor',
#  '00003307.jpg': 'museum-indoor',
#  '00001655.jpg': 'swimming_pool-outdoor',
#  '00006974.jpg': 'assembly_line',
#  '00004016.jpg': 'slum',
#  '00003978.jpg': 'assembly_line',
#  '00005088.jpg': 'baseball_field',
#  '00006811.jpg': 'auditorium',
#  '00004545.jpg': 'hospital_room',
#  '00004876.jpg': 'aqueduct',
#  '00004995.jpg': 'volcano',
#  '00000785.jpg': 'stadium-football',
#  '00005953.jpg': 'racecourse',
#  '00002849.jpg': 'courtyard',
#  '00004594.jpg': 'construction_site',
#  '00006916.jpg': 'valley',
#  '00000019.jpg': 'valley',
#  '00006679.jpg': 'laundromat',
#  '00006139.jpg': 'lobby',
#  '00003624.jpg': 'playground',
#  '00009622.jpg': 'bookstore',
#  '00005765.jpg': 'laundromat',
#  '00005551.jpg': 'food_court',
#  '00009474.jpg': 'museum-indoor',
#  '00001713.jpg': 'assembly_line',
#  '00000665.jpg': 'baseball_field',
#  '00007608.jpg': 'boxing_ring',
#  '00009946.jpg': 'phone_booth',
#  '00003069.jpg': 'auditorium',
#  '00006029.jpg': 'classroom',
#  '00007584.jpg': 'amusement_park',
#  '00004196.jpg': 'lighthouse',
#  '00007671.jpg': 'auditorium',
#  '00006344.jpg': 'skyscraper',
#  '00002072.jpg': 'abbey',
#  '00006411.jpg': 'shed',
#  '00003243.jpg': 'butchers_shop',
#  '00007600.jpg': 'swimming_pool-outdoor',
#  '00007138.jpg': 'supermarket',
#  '00009951.jpg': 'dining_room',
#  '00009697.jpg': 'bamboo_forest',
#  '00001846.jpg': 'mountain',
#  '00001559.jpg': 'construction_site',
#  '00000392.jpg': 'church-outdoor',
#  '00005130.jpg': 'candy_store',
#  '00007880.jpg': 'market-outdoor',
#  '00003296.jpg': 'laundromat',
#  '00007097.jpg': 'bowling_alley',
#  '00006098.jpg': 'corn_field',
#  '00003825.jpg': 'amusement_park',
#  '00001118.jpg': 'courtyard',
#  '00001637.jpg': 'candy_store',
#  '00002686.jpg': 'corn_field',
#  '00009554.jpg': 'courtyard',
#  '00004302.jpg': 'boat_deck',
#  '00003986.jpg': 'rainforest',
#  '00004968.jpg': 'harbor',
#  '00001177.jpg': 'boxing_ring',
#  '00002685.jpg': 'dam',
#  '00006711.jpg': 'coast',
#  '00000515.jpg': 'monastery-outdoor',
#  '00000979.jpg': 'lighthouse',
#  '00002518.jpg': 'cockpit',
#  '00001790.jpg': 'classroom',
#  '00000649.jpg': 'art_gallery',
#  '00000294.jpg': 'boxing_ring',
#  '00006169.jpg': 'butchers_shop',
#  '00005115.jpg': 'aquarium',
#  '00000399.jpg': 'badlands',
#  '00002784.jpg': 'river',
#  '00004664.jpg': 'parking_lot',
#  '00001325.jpg': 'kitchen',
#  '00003376.jpg': 'swamp',
#  '00000476.jpg': 'desert-sand',
#  '00000284.jpg': 'slum',
#  '00003639.jpg': 'temple-east_asia',
#  '00004743.jpg': 'candy_store',
#  '00000483.jpg': 'hot_spring',
#  '00008890.jpg': 'gas_station',
#  '00005380.jpg': 'swamp',
#  '00006515.jpg': 'bus_interior',
#  '00004858.jpg': 'butchers_shop',
#  '00004981.jpg': 'temple-east_asia',
#  '00000165.jpg': 'abbey',
#  '00004809.jpg': 'palace',
#  '00008014.jpg': 'art_gallery',
#  '00002170.jpg': 'swimming_pool-outdoor',
#  '00009069.jpg': 'fountain',
#  '00008167.jpg': 'fountain',
#  '00004242.jpg': 'hot_spring',
#  '00002901.jpg': 'bathroom',
#  '00002873.jpg': 'hospital_room',
#  '00003292.jpg': 'market-outdoor',
#  '00004072.jpg': 'yard',
#  '00004865.jpg': 'runway',
#  '00002379.jpg': 'bus_interior',
#  '00005779.jpg': 'banquet_hall',
#  '00004550.jpg': 'aqueduct',
#  '00008223.jpg': 'lobby',
#  '00007170.jpg': 'lobby',
#  '00000007.jpg': 'canyon',
#  '00009824.jpg': 'ice_skating_rink-outdoor',
#  '00002301.jpg': 'railroad_track',
#  '00001721.jpg': 'locker_room',
#  '00003393.jpg': 'yard',
#  '00008312.jpg': 'playground',
#  '00003107.jpg': 'iceberg',
#  '00007685.jpg': 'mountain',
#  '00001093.jpg': 'runway',
#  '00002314.jpg': 'museum-indoor',
#  '00002087.jpg': 'butchers_shop',
#  '00002029.jpg': 'river',
#  '00009258.jpg': 'locker_room',
#  '00006518.jpg': 'airport_terminal',
#  '00009380.jpg': 'bakery-shop',
#  '00002437.jpg': 'badlands',
#  '00005610.jpg': 'staircase',
#  '00004690.jpg': 'bowling_alley',
#  '00000784.jpg': 'coffee_shop',
#  '00004843.jpg': 'church-outdoor',
#  '00005183.jpg': 'construction_site',
#  '00006953.jpg': 'runway',
#  '00002051.jpg': 'bakery-shop',
#  '00002536.jpg': 'banquet_hall',
#  '00004502.jpg': 'yard',
#  '00002043.jpg': 'valley',
#  '00000510.jpg': 'monastery-outdoor',
#  '00005023.jpg': 'art_gallery',
#  '00008054.jpg': 'monastery-outdoor',
#  '00000965.jpg': 'ballroom',
#  '00009187.jpg': 'rainforest',
#  '00002193.jpg': 'bus_interior',
#  '00000168.jpg': 'construction_site',
#  '00006340.jpg': 'shower',
#  '00003449.jpg': 'ice_skating_rink-outdoor',
#  '00002999.jpg': 'badlands',
#  '00007256.jpg': 'aqueduct',
#  '00005080.jpg': 'amusement_park',
#  '00001018.jpg': 'dam',
#  '00001757.jpg': 'ballroom',
#  '00006860.jpg': 'church-outdoor',
#  '00005877.jpg': 'mountain',
#  '00006142.jpg': 'ice_skating_rink-outdoor',
#  '00006982.jpg': 'butchers_shop',
#  '00003152.jpg': 'auditorium',
#  '00004884.jpg': 'fountain',
#  '00008436.jpg': 'mountain',
#  '00000854.jpg': 'auditorium',
#  '00000421.jpg': 'rainforest',
#  '00006590.jpg': 'coffee_shop',
#  '00007632.jpg': 'monastery-outdoor',
#  '00006322.jpg': 'candy_store',
#  '00001696.jpg': 'golf_course',
#  '00009489.jpg': 'market-outdoor',
#  '00002194.jpg': 'bathroom',
#  '00002696.jpg': 'conference_room',
#  '00009085.jpg': 'bowling_alley',
#  '00002058.jpg': 'locker_room',
#  '00007621.jpg': 'art_gallery',
#  '00009386.jpg': 'volcano',
#  '00007802.jpg': 'airport_terminal',
#  '00009827.jpg': 'amphitheater',
#  '00006793.jpg': 'market-outdoor',
#  '00003850.jpg': 'bus_interior',
#  '00008613.jpg': 'valley',
#  '00004453.jpg': 'hot_spring',
#  '00001799.jpg': 'construction_site',
#  '00006429.jpg': 'corridor',
#  '00004571.jpg': 'iceberg',
#  '00007912.jpg': 'swamp',
#  '00007566.jpg': 'bedroom',
#  '00009865.jpg': 'auditorium',
#  '00001640.jpg': 'aquarium',
#  '00003201.jpg': 'art_gallery',
#  '00007660.jpg': 'valley',
#  '00003373.jpg': 'runway',
#  '00008861.jpg': 'aqueduct',
#  '00008068.jpg': 'coast',
#  '00006051.jpg': 'bus_interior',
#  '00004183.jpg': 'iceberg',
#  '00000138.jpg': 'mountain',
#  '00008675.jpg': 'staircase',
#  '00005433.jpg': 'chalet',
#  '00001209.jpg': 'market-outdoor',
#  '00004113.jpg': 'courtyard',
#  '00004519.jpg': 'botanical_garden',
#  '00008126.jpg': 'valley',
#  '00008459.jpg': 'harbor',
#  '00003859.jpg': 'clothing_store',
#  '00002396.jpg': 'corn_field',
#  '00005243.jpg': 'skyscraper',
#  '00004874.jpg': 'fire_station',
#  '00002067.jpg': 'monastery-outdoor',
#  '00001237.jpg': 'amphitheater',
#  '00004541.jpg': 'skyscraper',
#  '00003134.jpg': 'swamp',
#  '00004860.jpg': 'bakery-shop',
#  '00003597.jpg': 'ballroom',
#  '00006382.jpg': 'desert-sand',
#  '00003755.jpg': 'desert-sand',
#  '00000230.jpg': 'stadium-football',
#  '00004864.jpg': 'construction_site',
#  '00003545.jpg': 'coast',
#  '00002176.jpg': 'river',
#  '00006741.jpg': 'boxing_ring',
#  '00008202.jpg': 'clothing_store',
#  '00009718.jpg': 'bathroom',
#  '00009994.jpg': 'volcano',
#  '00009849.jpg': 'kitchen',
#  '00004074.jpg': 'museum-indoor',
#  '00007845.jpg': 'market-outdoor',
#  '00003872.jpg': 'conference_room',
#  '00001838.jpg': 'ski_slope',
#  '00001479.jpg': 'laundromat',
#  '00006101.jpg': 'bus_interior',
#  '00004199.jpg': 'temple-east_asia',
#  '00001147.jpg': 'stadium-football',
#  '00007099.jpg': 'corn_field',
#  '00001057.jpg': 'swamp',
#  '00004593.jpg': 'bar',
#  '00003003.jpg': 'bowling_alley',
#  '00000043.jpg': 'church-outdoor',
#  '00000275.jpg': 'lobby',
#  '00003110.jpg': 'iceberg',
#  '00006799.jpg': 'laundromat',
#  '00009392.jpg': 'phone_booth',
#  '00008636.jpg': 'courtyard',
#  '00006958.jpg': 'dining_room',
#  '00000076.jpg': 'botanical_garden',
#  '00007284.jpg': 'bus_interior',
#  '00000884.jpg': 'parking_lot',
#  '00002409.jpg': 'stage-indoor',
#  '00000725.jpg': 'staircase',
#  '00008554.jpg': 'campsite',
#  '00009903.jpg': 'martial_arts_gym',
#  '00001761.jpg': 'courtyard',
#  '00009534.jpg': 'ice_skating_rink-outdoor',
#  '00002283.jpg': 'slum',
#  '00005151.jpg': 'ice_skating_rink-outdoor',
#  '00008078.jpg': 'amusement_park',
#  '00008730.jpg': 'parking_lot',
#  '00000427.jpg': 'botanical_garden',
#  '00007547.jpg': 'swimming_pool-outdoor',
#  '00001676.jpg': 'track-outdoor',
#  '00005300.jpg': 'food_court',
#  '00007460.jpg': 'restaurant',
#  '00001130.jpg': 'coffee_shop',
#  '00006614.jpg': 'beauty_salon',
#  '00009762.jpg': 'bus_interior',
#  '00002942.jpg': 'stage-indoor',
#  '00000305.jpg': 'shed',
#  '00003823.jpg': 'coast',
#  '00002085.jpg': 'martial_arts_gym',
#  '00002207.jpg': 'corn_field',
#  '00006107.jpg': 'cockpit',
#  '00009941.jpg': 'canyon',
#  '00000639.jpg': 'corridor',
#  '00002441.jpg': 'trench',
#  '00005666.jpg': 'hospital_room',
#  '00004042.jpg': 'fire_station',
#  '00006743.jpg': 'yard',
#  '00003629.jpg': 'amusement_park',
#  '00000083.jpg': 'volcano',
#  '00005560.jpg': 'monastery-outdoor',
#  '00000112.jpg': 'kindergarden_classroom',
#  '00003915.jpg': 'playground',
#  '00008803.jpg': 'bar',
#  '00001726.jpg': 'living_room',
#  '00006059.jpg': 'canyon',
#  '00002871.jpg': 'phone_booth',
#  '00009821.jpg': 'kindergarden_classroom',
#  '00006259.jpg': 'shed',
#  '00006212.jpg': 'volcano',
#  '00004486.jpg': 'highway',
#  '00008135.jpg': 'bedroom',
#  '00005986.jpg': 'ski_slope',
#  '00007417.jpg': 'driveway',
#  '00000718.jpg': 'cemetery',
#  '00005861.jpg': 'bedroom',
#  '00008708.jpg': 'auditorium',
#  '00005206.jpg': 'ski_slope',
#  '00003502.jpg': 'ice_skating_rink-outdoor',
#  '00005619.jpg': 'boxing_ring',
#  '00002282.jpg': 'harbor',
#  '00006095.jpg': 'monastery-outdoor',
#  '00000390.jpg': 'rainforest',
#  '00004733.jpg': 'museum-indoor',
#  '00002954.jpg': 'laundromat',
#  '00003192.jpg': 'butchers_shop',
#  '00001971.jpg': 'temple-east_asia',
#  '00000128.jpg': 'highway',
#  '00003409.jpg': 'kindergarden_classroom',
#  '00008996.jpg': 'boat_deck',
#  '00000497.jpg': 'badlands',
#  '00005126.jpg': 'rock_arch',
#  '00000278.jpg': 'shower',
#  '00009677.jpg': 'supermarket',
#  '00002343.jpg': 'butchers_shop',
#  '00002069.jpg': 'corridor',
#  '00003591.jpg': 'fire_station',
#  '00007526.jpg': 'locker_room',
#  '00000273.jpg': 'fountain',
#  '00003389.jpg': 'fire_station',
#  '00005758.jpg': 'classroom',
#  '00003157.jpg': 'food_court',
#  '00007720.jpg': 'office',
#  '00005954.jpg': 'swamp',
#  '00005654.jpg': 'coffee_shop',
#  '00003956.jpg': 'stage-indoor',
#  '00003531.jpg': 'parking_lot',
#  '00001507.jpg': 'art_gallery',
#  '00000667.jpg': 'stadium-football',
#  '00002102.jpg': 'airport_terminal',
#  '00004549.jpg': 'office',
#  '00002487.jpg': 'dining_room',
#  '00001084.jpg': 'fountain',
#  '00006047.jpg': 'construction_site',
#  '00001966.jpg': 'bedroom',
#  '00000191.jpg': 'parking_lot',
#  '00000903.jpg': 'kitchen',
#  '00003886.jpg': 'abbey',
#  '00004673.jpg': 'bus_interior',
#  '00003272.jpg': 'kitchen',
#  '00002261.jpg': 'bus_interior',
#  '00005418.jpg': 'staircase',
#  '00001180.jpg': 'supermarket',
#  '00007071.jpg': 'runway',
#  '00001141.jpg': 'office',
#  '00003241.jpg': 'ski_slope',
#  '00004347.jpg': 'ballroom',
#  '00000058.jpg': 'butchers_shop',
#  '00002707.jpg': 'bathroom',
#  '00007955.jpg': 'bowling_alley',
#  '00000038.jpg': 'slum',
#  '00002160.jpg': 'stage-indoor',
#  '00001383.jpg': 'candy_store',
#  '00002630.jpg': 'hot_spring',
#  '00009744.jpg': 'valley',
#  '00007938.jpg': 'laundromat',
#  '00003773.jpg': 'rainforest',
#  '00004687.jpg': 'dining_room',
#  '00007019.jpg': 'swimming_pool-outdoor',
#  '00001968.jpg': 'bus_interior',
#  '00000317.jpg': 'aqueduct',
#  '00005704.jpg': 'laundromat',
#  '00007683.jpg': 'racecourse',
#  '00003159.jpg': 'racecourse',
#  '00006690.jpg': 'coffee_shop',
#  '00009348.jpg': 'restaurant',
#  '00002163.jpg': 'ice_skating_rink-outdoor',
#  '00007023.jpg': 'museum-indoor',
#  '00001357.jpg': 'kitchen',
#  '00000942.jpg': 'lighthouse',
#  '00008268.jpg': 'bathroom',
#  '00005284.jpg': 'airport_terminal',
#  '00002411.jpg': 'bathroom',
#  '00002398.jpg': 'parking_lot',
#  '00002964.jpg': 'track-outdoor',
#  '00002953.jpg': 'railroad_track',
#  '00009970.jpg': 'playground',
#  '00008363.jpg': 'coast',
#  '00005477.jpg': 'stadium-football',
#  '00000542.jpg': 'yard',
#  '00007864.jpg': 'palace',
#  '00000715.jpg': 'iceberg',
#  '00005537.jpg': 'temple-east_asia',
#  '00001127.jpg': 'railroad_track',
#  '00000063.jpg': 'monastery-outdoor',
#  '00000268.jpg': 'restaurant',
#  '00009299.jpg': 'staircase',
#  '00006884.jpg': 'baseball_field',
#  '00009743.jpg': 'monastery-outdoor',
#  '00009145.jpg': 'baseball_field',
#  '00006076.jpg': 'phone_booth',
#  '00004290.jpg': 'bar',
#  '00009480.jpg': 'art_gallery',
#  '00007316.jpg': 'rainforest',
#  '00001142.jpg': 'ski_slope',
#  '00004640.jpg': 'amphitheater',
#  '00002220.jpg': 'mountain',
#  '00007729.jpg': 'phone_booth',
#  '00005781.jpg': 'ski_slope',
#  '00005137.jpg': 'racecourse',
#  '00007970.jpg': 'candy_store',
#  '00002753.jpg': 'driveway',
#  '00009174.jpg': 'martial_arts_gym',
#  '00000473.jpg': 'shed',
#  '00000721.jpg': 'badlands',
#  '00005955.jpg': 'assembly_line',
#  '00003635.jpg': 'food_court',
#  '00002638.jpg': 'fire_station',
#  '00001547.jpg': 'museum-indoor',
#  '00003426.jpg': 'bookstore',
#  '00009149.jpg': 'driveway',
#  '00007238.jpg': 'office',
#  '00005247.jpg': 'highway',
#  '00003704.jpg': 'banquet_hall',
#  '00005507.jpg': 'bus_interior',
#  '00004600.jpg': 'fountain',
#  '00005480.jpg': 'conference_room',
#  '00002830.jpg': 'bridge',
#  '00000800.jpg': 'staircase',
#  '00005822.jpg': 'cemetery',
#  '00003961.jpg': 'volcano',
#  '00000826.jpg': 'shower',
#  '00002642.jpg': 'gas_station',
#  '00002479.jpg': 'canyon',
#  ...}

# %% [markdown]
# ## Do not run this code unless you need to preprocess!

# %%
# for cat in cat_num_to_name.values():
#     os.mkdir(os.path.join(VAL_PATH, cat))

# %%
# for fname, cat in filename_to_name.items():
#     src = os.path.join(VAL_PATH, fname)
#     dst = os.path.join(VAL_PATH, cat, fname)
#     os.rename(src, dst)

# %% [markdown]
# # Test Data
# Annotations for the test data will not be released! See `development_kit/README`

# %%
TEST_PATH = os.path.join(DATA_PATH, "test/")
TEST_PATH
# Out:
# '/afs/csail.mit.edu/u/j/jains/6869-places/data/images/test/'

# %% [markdown]
# # Look at the Data

# %%
def show(path, subpath, img_name):
    img_path = os.path.join(path, subpath, img_name)
    img = mpimg.imread(img_path)
    plt.imshow(img)
    plt.axis('off')
    plt.title(subpath)

# %%
import random
idx = random.randint(0,99)
category = categories[idx]

fnames = os.listdir(os.path.join(TRAIN_PATH, category))
fname = fnames[random.randint(0, len(fnames))]
show(TRAIN_PATH, category, fname)

# %% [markdown]
# # Make Model

# %%
import h5py
from DeepLearningModels import vgg19
model = vgg19.VGG19(weights=None, classes=len(categories))

print(model.summary())

# compile the model with crossentropy loss function.
model.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 100)               409700
# =================================================================
# Total params: 139,979,940
# Trainable params: 139,979,940
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Train the model

# %%
train_datagen = ImageDataGenerator()
train_generator = train_datagen.flow_from_directory(TRAIN_PATH, batch_size=16, classes=categories, target_size=(224,224))
# Out:
# Found 100000 images belonging to 100 classes.

# %%
val_datagen = ImageDataGenerator()
val_generator = val_datagen.flow_from_directory(VAL_PATH, classes=categories, target_size=(224, 224))
# Out:
# Found 10000 images belonging to 100 classes.

# %%
saver_cb = keras.callbacks.ModelCheckpoint('my_model-vgg19-train-cb-new.h5', monitor='val_loss', verbose=1, save_best_only=True)
model.fit_generator(
        train_generator,
        steps_per_epoch=int(train_generator.samples/train_generator.batch_size),
        epochs=10,
        callbacks=[saver_cb],
        validation_data=val_generator,
        validation_steps=int(val_generator.samples/val_generator.batch_size))
# Out:
# Epoch 1/10
# 4543/6250 [====================>.........] - ETA: 885s - loss: 15.9547 - acc: 0.0101
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-47c372d3befb> in <module>()
#       6         callbacks=[saver_cb],
#       7         validation_data=val_generator,
# ----> 8         validation_steps=int(val_generator.samples/val_generator.batch_size))
#
# ~/6869-places/venv3/lib/python3.4/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# ~/6869-places/venv3/lib/python3.4/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1900                     outs = self.train_on_batch(x, y,
#    1901                                                sample_weight=sample_weight,
# -> 1902                                                class_weight=class_weight)
#    1903
#    1904                     if not isinstance(outs, list):
#
# ~/6869-places/venv3/lib/python3.4/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1640             ins = x + y + sample_weights
#    1641         self._make_train_function()
# -> 1642         outputs = self.train_function(ins)
#    1643         if len(outputs) == 1:
#    1644             return outputs[0]
#
# ~/6869-places/venv3/lib/python3.4/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2267         updated = session.run(self.outputs + [self.updates_op],
#    2268                               feed_dict=feed_dict,
# -> 2269                               **self.session_kwargs)
#    2270         return updated[:len(self.outputs)]
#    2271
#
# ~/6869-places/venv3/lib/python3.4/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/6869-places/venv3/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# ~/6869-places/venv3/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/6869-places/venv3/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# ~/6869-places/venv3/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model.save('my_model-vgg19-train-new.h5')

# %%
model = keras.models.load_model('my_model-vgg19-train-cb-new.h5')

# %% [markdown]
# # Test on Validation Set

# %%
result = model.evaluate_generator(
    val_generator,
    steps=int(val_generator.samples/val_generator.batch_size)
)
print("Loss on validation set:"  + str(result[0]) + " Accuracy on validation set: " + str(result[1]))

# %% [markdown]
# # Inference on Test Set

# %%
test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(TEST_PATH, target_size=(224,224))

# %%
result = model.predict_generator(
    test_generator,
    steps=int(test_generator.samples/test_generator.batch_size)

# %%
TEST_PATH
